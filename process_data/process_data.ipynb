# %%
import numpy as np
import pandas as pd

#DATA
NigUni="NigerianUniversity"

def open_data(path):
    return path

data = open_data(f'../data/{NigUni}.csv')

# %%
df = pd.read_csv(data)
df
# Out:
#     info_id                                               name       location  \
# 0       1.0                         Adekunle Ajasin University  Akungba-Akoko
# 1       2.0                            Afe Babalola University      Ado Ekiti
# 2       3.0                                 Caritas University          Enugu
# 3       4.0               Cross River University of Technology        Calabar
# 4       5.0   Enugu State University of Science and Technology          Enugu
# ..      ...                                                ...            ...
# 80     81.0                            Bauchi State University          Gadau
# 81     82.0                    Abubakar Tatari Ali Polytechnic         Bauchi
# 82     83.0  Nigerian Army University Biu (NAUB) Ajasin Uni...           Ondo
# 83      NaN                                                NaN            NaN
# 84      NaN                                                NaN            NaN
#
# ...

# %%
import pymysql as mysql
from sqlalchemy import create_engine

db_connection = mysql.connect(host='192.168.64.2',
database='Easysearch', user='ola', password='rkEVq9Z9gZXIsRem')
df.to_sql("info", db_connection,if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Documents/code/EasySearch/env/lib/python3.9/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# ~/Documents/code/EasySearch/env/lib/python3.9/site-packages/pymysql/cursors.py in execute(self, query, args)
#     145
# --> 146         query = self.mogrify(query, args)
#     147
#
# ~/Documents/code/EasySearch/env/lib/python3.9/site-packages/pymysql/cursors.py in mogrify(self, query, args)
#     124         if args is not None:
# --> 125             query = query % self._escape_args(args, conn)
#     126
#
# TypeError: not all arguments converted during string formatting
#
# The above exception was the direct cause of the following exception:
#
# ...
